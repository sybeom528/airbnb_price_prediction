# %%
# 데이터 처리 및 분석
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import warnings

# 경로 설정
import os 
import sys

# 시각화
import matplotlib.pyplot as plt
import seaborn as sns

# 출력 설정
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# 한글 폰트 설정
import platform
if platform.system() == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'
elif platform.system() == 'Darwin':
    plt.rcParams['font.family'] = 'AppleGothic'
else:
    plt.rcParams['font.family'] = 'NanumGothic'

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.figsize'] = (12,6)

# 시드 설정
np.random.seed(42)

print('-' * 60)
print('라이브러리 로드 완료')
print('한글 폰트 설정 완료!')
print('-'* 60)
# Out:
# ------------------------------------------------------------
# 라이브러리 로드 완료
# 한글 폰트 설정 완료!
# ------------------------------------------------------------

# %%
# 현재 작업 디렉토리(notebooks)의 부모 디렉토리(root)를 경로에 추가
os.chdir(os.path.abspath('..'))
print(os.getcwd())

df = pd.read_csv('data/2025_Airbnb_NYC_listings.csv').drop(columns = 'Unnamed: 0')
df.head()
# Out:
# c:\workspace\camp\project\airbnb_price_prediction
#       id       source                                               name  \
# 0  36121  city scrape                 Lg Rm in Historic Prospect Heights
# 1  36647  city scrape  1 Bedroom & your own Bathroom, Elevator Apartment
# 2  38663  city scrape                   Luxury Brownstone in Boerum Hill
# 3  38833  city scrape                 Spectacular West Harlem Garden Apt
# 4  39282  city scrape                    “Work-from-home” from OUR home.
#
#                                          description  \
# 0  Cozy space share in the heart of a great neigh...
# 1  Private bedroom with your own bathroom in a 2 ...
# 2  Beautiful, large home in great hipster neighbo...
# 3  This is a very large and unique  space. An inc...
# 4  *Monthly Discount will automatically apply <br...
#
#                                neighborhood_overview  host_id host_name  \
# 0  Full of tree-lined streets and beautiful brown...    62165   Michael
# 1   Manhattan, SE corner of 2nd Ave/ E. 110th street   157798     Irene
# 2  diverse, lively, hip, cool: loaded with restau...   165789     Sarah
# 3  West Harlem is now packed with great restauran...   166532   Matthew
# 4  THE NEIGHBORHOOD:<br />Our apartment is locate...   168525   Gustavo
#
#    host_since host_location  \
# 0  2009-12-11  New York, NY
# 1  2010-07-04  New York, NY
# 2  2010-07-13  New York, NY
# 3  2010-07-14  New York, NY
# 4  2010-07-16  New York, NY
#
#                                           host_about  host_response_time  \
# 0  I’m an urban planner working for an internatio...                 NaN
# 1                                                NaN                 NaN
# 2  I am a lawyer and work as an executive at an a...  within a few hours
# 3  I have been a New Yorker for a long time\n and...      within an hour
# 4  I am a music producer. And my wife is a hair s...      within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                  NaN                 f
# 1                NaN                 100%                 f
# 2               100%                  40%                 f
# 3               100%                  97%                 t
# 4               100%                 100%                 t
#
#   host_neighbourhood  host_listings_count  host_total_listings_count  \
# 0   Prospect Heights                  1.0                        3.0
# 1        East Harlem                  1.0                        1.0
# 2        Boerum Hill                  1.0                        3.0
# 3             Harlem                  1.0                        1.0
# 4       Williamsburg                  2.0                        2.0
#
#                  host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'work_email']                    t
# 1                ['email', 'phone']                    t
# 2  ['email', 'phone', 'work_email']                    t
# 3                ['email', 'phone']                    t
# 4                ['email', 'phone']                    t
#
#   host_identity_verified            neighbourhood neighbourhood_cleansed  \
# 0                      t  Neighborhood highlights       Prospect Heights
# 1                      t  Neighborhood highlights            East Harlem
# 2                      t  Neighborhood highlights            Boerum Hill
# 3                      t  Neighborhood highlights                 Harlem
# 4                      t  Neighborhood highlights           Williamsburg
#
#   neighbourhood_group_cleansed   latitude  longitude  \
# 0                     Brooklyn  40.673760 -73.966110
# 1                    Manhattan  40.792454 -73.940742
# 2                     Brooklyn  40.684420 -73.980680
# 3                    Manhattan  40.818058 -73.946671
# 4                     Brooklyn  40.710651 -73.950874
#
#                  property_type        room_type  accommodates  bathrooms  \
# 0  Private room in rental unit     Private room             1        1.0
# 1        Private room in condo     Private room             2        1.0
# 2         Private room in home     Private room             2        2.5
# 3                  Entire home  Entire home/apt             2        1.0
# 4  Private room in rental unit     Private room             2        1.0
#
#    bathrooms_text  bedrooms  beds  \
# 0   1 shared bath       1.0   1.0
# 1  1 private bath       1.0   1.0
# 2       2.5 baths       5.0   5.0
# 3          1 bath       1.0   1.0
# 4   1 shared bath       1.0   1.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Refrigerator", "Dishes and silverware", "Wif...  $200.00              90
# 1  ["Oven", "Blender", "Luggage dropoff allowed",...   $82.00              30
# 2  ["Portable fans", "Oven", "Baking sheet", "Fir...  $765.00               3
# 3  ["Fire extinguisher", "Clothing storage: close...  $139.00               2
# 4  ["Oven", "Rice maker", "Laundromat nearby", "L...  $130.00               4
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0             365                    90.0                    90.0
# 1             999                    30.0                    30.0
# 2              60                     3.0                     3.0
# 3              45                     2.0                     2.0
# 4              45                     4.0                     4.0
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                   365.0                   365.0                    90.0
# 1                   999.0                   999.0                    30.0
# 2                    60.0                    60.0                     3.0
# 3                  1125.0                  1125.0                     2.0
# 4                    45.0                    45.0                     4.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                   365.0               NaN                t               27
# 1                   999.0               NaN                t                0
# 2                    60.0               NaN                t               30
# 3                  1125.0               NaN                t                7
# 4                    45.0               NaN                t               14
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               57               87               362            2025-03-03
# 1                0                0               204            2025-03-03
# 2               49               66               326            2025-03-02
# 3               18               25                25            2025-03-03
# 4               22               38                38            2025-03-02
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                  9                      0                       0
# 1                102                      0                       0
# 2                 43                      0                       0
# 3                241                     42                       3
# 4                274                     12                       0
#
#    availability_eoy  number_of_reviews_ly  estimated_occupancy_l365d  \
# 0               301                     0                          0
# 1               143                     0                          0
# 2               267                     0                          0
# 3                25                    43                        255
# 4                38                    12                        154
#
#    estimated_revenue_l365d first_review last_review  review_scores_rating  \
# 0                      0.0   2010-12-11  2013-05-10                  4.88
# 1                      0.0   2010-10-04  2023-12-09                  4.77
# 2                      0.0   2012-07-09  2023-08-30                  4.70
# 3                  35445.0   2010-08-28  2025-02-21                  4.85
# 4                  20020.0   2010-08-02  2025-01-03                  4.82
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    5.00                       4.80                   5.00
# 1                    4.82                       4.76                   4.88
# 2                    4.83                       4.52                   4.88
# 3                    4.87                       4.50                   4.96
# 4                    4.83                       4.61                   4.94
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         5.00                    5.00                 5.00
# 1                         4.90                    4.38                 4.71
# 2                         4.88                    4.86                 4.62
# 3                         4.96                    4.79                 4.82
# 4                         4.88                    4.85                 4.78
#
#               license instant_bookable  calculated_host_listings_count  \
# 0                 NaN                f                               1
# 1                 NaN                f                               1
# 2  OSE-STRREG-0001784                f                               1
# 3  OSE-STRREG-0000476                f                               1
# 4  OSE-STRREG-0001150                f                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            1
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             1
# 2                                             1
# 3                                             0
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.05
# 1                                            0               0.58
# 2                                            0               0.28
# 3                                            0               1.36
# 4                                            0               1.54

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 22308 entries, 0 to 22307
# Data columns (total 72 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            22308 non-null  int64
#  1   source                                        22308 non-null  str
#  2   name                                          22308 non-null  str
#  3   description                                   21903 non-null  str
#  4   neighborhood_overview                         12262 non-null  str
#  5   host_id                                       22308 non-null  int64
#  6   host_name                                     22288 non-null  str
#  7   host_since                                    22288 non-null  str
#  8   host_location                                 17025 non-null  str
#  9   host_about                                    13391 non-null  str
#  10  host_response_time                            17915 non-null  str
#  11  host_response_rate                            17915 non-null  str
#  12  host_acceptance_rate                          18842 non-null  str
#  13  host_is_superhost                             21934 non-null  str
#  14  host_neighbourhood                            17578 non-null  str
#  15  host_listings_count                           22288 non-null  float64
#  16  host_total_listings_count                     22288 non-null  float64
#  17  host_verifications                            22288 non-null  str
#  18  host_has_profile_pic                          22288 non-null  str
#  19  host_identity_verified                        22288 non-null  str
#  20  neighbourhood                                 12262 non-null  str
#  21  neighbourhood_cleansed                        22308 non-null  str
#  22  neighbourhood_group_cleansed                  22308 non-null  str
#  23  latitude                                      22308 non-null  float64
#  24  longitude                                     22308 non-null  float64
#  25  property_type                                 22308 non-null  str
#  26  room_type                                     22308 non-null  str
#  27  accommodates                                  22308 non-null  int64
#  28  bathrooms                                     22302 non-null  float64
#  29  bathrooms_text                                22294 non-null  str
#  30  bedrooms                                      22259 non-null  float64
#  31  beds                                          22229 non-null  float64
#  32  amenities                                     22308 non-null  str
#  33  price                                         22308 non-null  str
#  34  minimum_nights                                22308 non-null  int64
#  35  maximum_nights                                22308 non-null  int64
#  36  minimum_minimum_nights                        22308 non-null  float64
#  37  maximum_minimum_nights                        22308 non-null  float64
#  38  minimum_maximum_nights                        22308 non-null  float64
#  39  maximum_maximum_nights                        22308 non-null  float64
#  40  minimum_nights_avg_ntm                        22308 non-null  float64
#  41  maximum_nights_avg_ntm                        22308 non-null  float64
#  42  calendar_updated                              0 non-null      float64
#  43  has_availability                              22062 non-null  str
#  44  availability_30                               22308 non-null  int64
#  45  availability_60                               22308 non-null  int64
#  46  availability_90                               22308 non-null  int64
#  47  availability_365                              22308 non-null  int64
#  48  calendar_last_scraped                         22308 non-null  str
#  49  number_of_reviews                             22308 non-null  int64
#  50  number_of_reviews_ltm                         22308 non-null  int64
#  51  number_of_reviews_l30d                        22308 non-null  int64
#  52  availability_eoy                              22308 non-null  int64
#  53  number_of_reviews_ly                          22308 non-null  int64
#  54  estimated_occupancy_l365d                     22308 non-null  int64
#  55  estimated_revenue_l365d                       22308 non-null  float64
#  56  first_review                                  15510 non-null  str
#  57  last_review                                   15510 non-null  str
#  58  review_scores_rating                          15510 non-null  float64
#  59  review_scores_accuracy                        15510 non-null  float64
#  60  review_scores_cleanliness                     15510 non-null  float64
#  61  review_scores_checkin                         15510 non-null  float64
#  62  review_scores_communication                   15510 non-null  float64
#  63  review_scores_location                        15509 non-null  float64
#  64  review_scores_value                           15510 non-null  float64
#  65  license                                       4463 non-null   str
#  66  instant_bookable                              22308 non-null  str
#  67  calculated_host_listings_count                22308 non-null  int64
#  68  calculated_host_listings_count_entire_homes   22308 non-null  int64
#  69  calculated_host_listings_count_private_rooms  22308 non-null  int64
#  70  calculated_host_listings_count_shared_rooms   22308 non-null  int64
#  71  reviews_per_month                             15510 non-null  float64
# dtypes: float64(23), int64(19), str(30)
# memory usage: 12.3 MB

# %%
df.describe(include='all').T
# Out:
#                                                 count unique  \
# id                                            22308.0    NaN
# source                                          22308      1
# name                                            22308  21342
# description                                     21903  17854
# neighborhood_overview                           12262   8232
# host_id                                       22308.0    NaN
# host_name                                       22288   5343
# host_since                                      22288   4567
# host_location                                   17025    421
# host_about                                      13391   5804
# host_response_time                              17915      4
# host_response_rate                              17915     65
# host_acceptance_rate                            18842     96
# host_is_superhost                               21934      2
# host_neighbourhood                              17578    446
# host_listings_count                           22288.0    NaN
# host_total_listings_count                     22288.0    NaN
# host_verifications                              22288      6
# host_has_profile_pic                            22288      2
# host_identity_verified                          22288      2
# neighbourhood                                   12262      1
# neighbourhood_cleansed                          22308    221
# neighbourhood_group_cleansed                    22308      5
# latitude                                      22308.0    NaN
# longitude                                     22308.0    NaN
# property_type                                   22308     57
# room_type                                       22308      4
# accommodates                                  22308.0    NaN
# bathrooms                                     22302.0    NaN
# bathrooms_text                                  22294     31
# bedrooms                                      22259.0    NaN
# beds                                          22229.0    NaN
# amenities                                       22308  18410
# price                                           22308   1022
# minimum_nights                                22308.0    NaN
# maximum_nights                                22308.0    NaN
# minimum_minimum_nights                        22308.0    NaN
# maximum_minimum_nights                        22308.0    NaN
# minimum_maximum_nights                        22308.0    NaN
# maximum_maximum_nights                        22308.0    NaN
# minimum_nights_avg_ntm                        22308.0    NaN
# maximum_nights_avg_ntm                        22308.0    NaN
# calendar_updated                                  0.0    NaN
# has_availability                                22062      1
# availability_30                               22308.0    NaN
# availability_60                               22308.0    NaN
# availability_90                               22308.0    NaN
# availability_365                              22308.0    NaN
# calendar_last_scraped                           22308      2
# number_of_reviews                             22308.0    NaN
# number_of_reviews_ltm                         22308.0    NaN
# number_of_reviews_l30d                        22308.0    NaN
# availability_eoy                              22308.0    NaN
# number_of_reviews_ly                          22308.0    NaN
# estimated_occupancy_l365d                     22308.0    NaN
# estimated_revenue_l365d                       22308.0    NaN
# first_review                                    15510   3755
# last_review                                     15510   1694
# review_scores_rating                          15510.0    NaN
# review_scores_accuracy                        15510.0    NaN
# review_scores_cleanliness                     15510.0    NaN
# review_scores_checkin                         15510.0    NaN
# review_scores_communication                   15510.0    NaN
# review_scores_location                        15509.0    NaN
# review_scores_value                           15510.0    NaN
# license                                          4463   1894
# instant_bookable                                22308      2
# calculated_host_listings_count                22308.0    NaN
# calculated_host_listings_count_entire_homes   22308.0    NaN
# calculated_host_listings_count_private_rooms  22308.0    NaN
# calculated_host_listings_count_shared_rooms   22308.0    NaN
# reviews_per_month                             15510.0    NaN
#
#                                                                                             top  \
# id                                                                                          NaN
# source                                                                              city scrape
# name                                            Wyndham Midtown 45 Resort | King Bed Hotel Room
# description                                   Keep it simple at this peaceful and centrally-...
# neighborhood_overview                         This furnished property is located on the Uppe...
# host_id                                                                                     NaN
# host_name                                                                            Blueground
# host_since                                                                           2016-12-16
# host_location                                                                      New York, NY
# host_about                                    We’re Blueground, a global proptech company wi...
# host_response_time                                                               within an hour
# host_response_rate                                                                         100%
# host_acceptance_rate                                                                       100%
# host_is_superhost                                                                             f
# host_neighbourhood                                                           Bedford-Stuyvesant
# host_listings_count                                                                         NaN
# host_total_listings_count                                                                   NaN
# host_verifications                                                           ['email', 'phone']
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# neighbourhood                                                           Neighborhood highlights
# neighbourhood_cleansed                                                       Bedford-Stuyvesant
# neighbourhood_group_cleansed                                                          Manhattan
# latitude                                                                                    NaN
# longitude                                                                                   NaN
# property_type                                                                Entire rental unit
# room_type                                                                       Entire home/apt
# accommodates                                                                                NaN
# bathrooms                                                                                   NaN
# bathrooms_text                                                                           1 bath
# bedrooms                                                                                    NaN
# beds                                                                                        NaN
# amenities                                     ["Air conditioning", "Carbon monoxide alarm", ...
# price                                                                                   $150.00
# minimum_nights                                                                              NaN
# maximum_nights                                                                              NaN
# minimum_minimum_nights                                                                      NaN
# maximum_minimum_nights                                                                      NaN
# minimum_maximum_nights                                                                      NaN
# maximum_maximum_nights                                                                      NaN
# minimum_nights_avg_ntm                                                                      NaN
# maximum_nights_avg_ntm                                                                      NaN
# calendar_updated                                                                            NaN
# has_availability                                                                              t
# availability_30                                                                             NaN
# availability_60                                                                             NaN
# availability_90                                                                             NaN
# availability_365                                                                            NaN
# calendar_last_scraped                                                                2025-03-02
# number_of_reviews                                                                           NaN
# number_of_reviews_ltm                                                                       NaN
# number_of_reviews_l30d                                                                      NaN
# availability_eoy                                                                            NaN
# number_of_reviews_ly                                                                        NaN
# estimated_occupancy_l365d                                                                   NaN
# estimated_revenue_l365d                                                                     NaN
# first_review                                                                         2023-01-01
# last_review                                                                          2025-02-16
# review_scores_rating                                                                        NaN
# review_scores_accuracy                                                                      NaN
# review_scores_cleanliness                                                                   NaN
# review_scores_checkin                                                                       NaN
# review_scores_communication                                                                 NaN
# review_scores_location                                                                      NaN
# review_scores_value                                                                         NaN
# license                                                                                  Exempt
# instant_bookable                                                                              f
# calculated_host_listings_count                                                              NaN
# calculated_host_listings_count_entire_homes                                                 NaN
# calculated_host_listings_count_private_rooms                                                NaN
# calculated_host_listings_count_shared_rooms                                                 NaN
# reviews_per_month                                                                           NaN
#
#                                                freq                  mean  \
# id                                              NaN  594931827143523456.0
# source                                        22308                   NaN
# name                                             14                   NaN
# description                                      72                   NaN
# neighborhood_overview                           106                   NaN
# host_id                                         NaN      216347621.868881
# host_name                                      1094                   NaN
# host_since                                     1096                   NaN
# host_location                                 13441                   NaN
# host_about                                     1094                   NaN
# host_response_time                            11645                   NaN
# host_response_rate                            12885                   NaN
# host_acceptance_rate                           4909                   NaN
# host_is_superhost                             15799                   NaN
# host_neighbourhood                             1138                   NaN
# host_listings_count                             NaN            394.298771
# host_total_listings_count                       NaN            494.859027
# host_verifications                            16852                   NaN
# host_has_profile_pic                          21646                   NaN
# host_identity_verified                        20423                   NaN
# neighbourhood                                 12262                   NaN
# neighbourhood_cleansed                         1545                   NaN
# neighbourhood_group_cleansed                  10205                   NaN
# latitude                                        NaN             40.729287
# longitude                                       NaN            -73.944752
# property_type                                  9648                   NaN
# room_type                                     12664                   NaN
# accommodates                                    NaN              2.919446
# bathrooms                                       NaN              1.192897
# bathrooms_text                                11281                   NaN
# bedrooms                                        NaN              1.315468
# beds                                            NaN              1.646318
# amenities                                       241                   NaN
# price                                           376                   NaN
# minimum_nights                                  NaN             27.249417
# maximum_nights                                  NaN            473.223104
# minimum_minimum_nights                          NaN             27.004348
# maximum_minimum_nights                          NaN              42.13215
# minimum_maximum_nights                          NaN          96832.649991
# maximum_maximum_nights                          NaN        1733373.071096
# minimum_nights_avg_ntm                          NaN               28.2289
# maximum_nights_avg_ntm                          NaN          939166.04783
# calendar_updated                                NaN                   NaN
# has_availability                              22062                   NaN
# availability_30                                 NaN             16.472969
# availability_60                                 NaN             36.161243
# availability_90                                 NaN              57.37834
# availability_365                                NaN            239.724718
# calendar_last_scraped                         16471                   NaN
# number_of_reviews                               NaN             34.353102
# number_of_reviews_ltm                           NaN              6.137081
# number_of_reviews_l30d                          NaN              0.320916
# availability_eoy                                NaN            204.026672
# number_of_reviews_ly                            NaN               5.91438
# estimated_occupancy_l365d                       NaN             71.562713
# estimated_revenue_l365d                         NaN          11901.936525
# first_review                                     52                   NaN
# last_review                                     217                   NaN
# review_scores_rating                            NaN              4.724384
# review_scores_accuracy                          NaN              4.752921
# review_scores_cleanliness                       NaN              4.687651
# review_scores_checkin                           NaN              4.831479
# review_scores_communication                     NaN              4.813298
# review_scores_location                          NaN              4.729518
# review_scores_value                             NaN              4.613484
# license                                        2064                   NaN
# instant_bookable                              16618                   NaN
# calculated_host_listings_count                  NaN              89.47279
# calculated_host_listings_count_entire_homes     NaN             74.823247
# calculated_host_listings_count_private_rooms    NaN              12.25009
# calculated_host_listings_count_shared_rooms     NaN              0.017931
# reviews_per_month                               NaN              1.159966
#
#                                                                std        min  \
# id                                            516864910912614336.0     6848.0
# source                                                         NaN        NaN
# name                                                           NaN        NaN
# description                                                    NaN        NaN
# neighborhood_overview                                          NaN        NaN
# host_id                                            202510512.17774     1678.0
# host_name                                                      NaN        NaN
# host_since                                                     NaN        NaN
# host_location                                                  NaN        NaN
# host_about                                                     NaN        NaN
# host_response_time                                             NaN        NaN
# host_response_rate                                             NaN        NaN
# host_acceptance_rate                                           NaN        NaN
# host_is_superhost                                              NaN        NaN
# host_neighbourhood                                             NaN        NaN
# host_listings_count                                    1260.543854        1.0
# host_total_listings_count                              1484.648457        1.0
# host_verifications                                             NaN        NaN
# host_has_profile_pic                                           NaN        NaN
# host_identity_verified                                         NaN        NaN
# neighbourhood                                                  NaN        NaN
# neighbourhood_cleansed                                         NaN        NaN
# neighbourhood_group_cleansed                                   NaN        NaN
# latitude                                                  0.058453  40.500366
# longitude                                                  0.05938 -74.251907
# property_type                                                  NaN        NaN
# room_type                                                      NaN        NaN
# accommodates                                              2.073278        1.0
# bathrooms                                                  0.55667        0.0
# bathrooms_text                                                 NaN        NaN
# bedrooms                                                  0.918378        0.0
# beds                                                      1.200619        0.0
# amenities                                                      NaN        NaN
# price                                                          NaN        NaN
# minimum_nights                                           32.428943        1.0
# maximum_nights                                          407.843202        1.0
# minimum_minimum_nights                                   32.120852        1.0
# maximum_minimum_nights                                   74.697642        1.0
# minimum_maximum_nights                             14378031.571626        1.0
# maximum_maximum_nights                             60977572.219254        1.0
# minimum_nights_avg_ntm                                   37.370579        1.0
# maximum_nights_avg_ntm                             42264392.871396        1.0
# calendar_updated                                               NaN        NaN
# has_availability                                               NaN        NaN
# availability_30                                          12.858508        0.0
# availability_60                                          23.705578        0.0
# availability_90                                           33.53838        0.0
# availability_365                                        112.168551        0.0
# calendar_last_scraped                                          NaN        NaN
# number_of_reviews                                        76.783685        0.0
# number_of_reviews_ltm                                    24.604144        0.0
# number_of_reviews_l30d                                    1.876082        0.0
# availability_eoy                                         93.441009        0.0
# number_of_reviews_ly                                     24.116508        0.0
# estimated_occupancy_l365d                                96.622429        0.0
# estimated_revenue_l365d                               24186.923458        0.0
# first_review                                                   NaN        NaN
# last_review                                                    NaN        NaN
# review_scores_rating                                      0.457137        1.0
# review_scores_accuracy                                    0.439686        1.0
# review_scores_cleanliness                                 0.468699        1.0
# review_scores_checkin                                      0.37089        1.0
# review_scores_communication                               0.419805        1.0
# review_scores_location                                    0.389415        1.0
# review_scores_value                                       0.504365        1.0
# license                                                        NaN        NaN
# instant_bookable                                               NaN        NaN
# calculated_host_listings_count                          263.516627        1.0
# calculated_host_listings_count_entire_homes             259.293166        0.0
# calculated_host_listings_count_private_rooms             59.627479        0.0
# calculated_host_listings_count_shared_rooms               0.196899        0.0
# reviews_per_month                                         2.223845       0.01
#
#                                                       25%  \
# id                                            41372693.25
# source                                                NaN
# name                                                  NaN
# description                                           NaN
# neighborhood_overview                                 NaN
# host_id                                        27181542.0
# host_name                                             NaN
# host_since                                            NaN
# host_location                                         NaN
# host_about                                            NaN
# host_response_time                                    NaN
# host_response_rate                                    NaN
# host_acceptance_rate                                  NaN
# host_is_superhost                                     NaN
# host_neighbourhood                                    NaN
# host_listings_count                                   1.0
# host_total_listings_count                             2.0
# host_verifications                                    NaN
# host_has_profile_pic                                  NaN
# host_identity_verified                                NaN
# neighbourhood                                         NaN
# neighbourhood_cleansed                                NaN
# neighbourhood_group_cleansed                          NaN
# latitude                                         40.68713
# longitude                                      -73.983623
# property_type                                         NaN
# room_type                                             NaN
# accommodates                                          2.0
# bathrooms                                             1.0
# bathrooms_text                                        NaN
# bedrooms                                              1.0
# beds                                                  1.0
# amenities                                             NaN
# price                                                 NaN
# minimum_nights                                       30.0
# maximum_nights                                      120.0
# minimum_minimum_nights                               30.0
# maximum_minimum_nights                               30.0
# minimum_maximum_nights                              182.0
# maximum_maximum_nights                              365.0
# minimum_nights_avg_ntm                               30.0
# maximum_nights_avg_ntm                              360.0
# calendar_updated                                      NaN
# has_availability                                      NaN
# availability_30                                       1.0
# availability_60                                      12.0
# availability_90                                      29.0
# availability_365                                    151.0
# calendar_last_scraped                                 NaN
# number_of_reviews                                     0.0
# number_of_reviews_ltm                                 0.0
# number_of_reviews_l30d                                0.0
# availability_eoy                                    126.0
# number_of_reviews_ly                                  0.0
# estimated_occupancy_l365d                             0.0
# estimated_revenue_l365d                               0.0
# first_review                                          NaN
# last_review                                           NaN
# review_scores_rating                               4.6625
# review_scores_accuracy                                4.7
# review_scores_cleanliness                             4.6
# review_scores_checkin                                4.81
# review_scores_communication                           4.8
# review_scores_location                               4.64
# review_scores_value                                  4.51
# license                                               NaN
# instant_bookable                                      NaN
# calculated_host_listings_count                        1.0
# calculated_host_listings_count_entire_homes           0.0
# calculated_host_listings_count_private_rooms          0.0
# calculated_host_listings_count_shared_rooms           0.0
# reviews_per_month                                    0.18
#
#                                                                50%  \
# id                                            727563706116818176.0
# source                                                         NaN
# name                                                           NaN
# description                                                    NaN
# neighborhood_overview                                          NaN
# host_id                                                137358866.0
# host_name                                                      NaN
# host_since                                                     NaN
# host_location                                                  NaN
# host_about                                                     NaN
# host_response_time                                             NaN
# host_response_rate                                             NaN
# host_acceptance_rate                                           NaN
# host_is_superhost                                              NaN
# host_neighbourhood                                             NaN
# host_listings_count                                            3.0
# host_total_listings_count                                      5.0
# host_verifications                                             NaN
# host_has_profile_pic                                           NaN
# host_identity_verified                                         NaN
# neighbourhood                                                  NaN
# neighbourhood_cleansed                                         NaN
# neighbourhood_group_cleansed                                   NaN
# latitude                                                  40.73033
# longitude                                               -73.954485
# property_type                                                  NaN
# room_type                                                      NaN
# accommodates                                                   2.0
# bathrooms                                                      1.0
# bathrooms_text                                                 NaN
# bedrooms                                                       1.0
# beds                                                           1.0
# amenities                                                      NaN
# price                                                          NaN
# minimum_nights                                                30.0
# maximum_nights                                               365.0
# minimum_minimum_nights                                        30.0
# maximum_minimum_nights                                        30.0
# minimum_maximum_nights                                       365.0
# maximum_maximum_nights                                       365.0
# minimum_nights_avg_ntm                                        30.0
# maximum_nights_avg_ntm                                       365.0
# calendar_updated                                               NaN
# has_availability                                               NaN
# availability_30                                               21.0
# availability_60                                               43.0
# availability_90                                               66.0
# availability_365                                             269.0
# calendar_last_scraped                                          NaN
# number_of_reviews                                              5.0
# number_of_reviews_ltm                                          0.0
# number_of_reviews_l30d                                         0.0
# availability_eoy                                             228.0
# number_of_reviews_ly                                           0.0
# estimated_occupancy_l365d                                      0.0
# estimated_revenue_l365d                                        0.0
# first_review                                                   NaN
# last_review                                                    NaN
# review_scores_rating                                          4.85
# review_scores_accuracy                                        4.88
# review_scores_cleanliness                                     4.83
# review_scores_checkin                                         4.94
# review_scores_communication                                   4.94
# review_scores_location                                        4.82
# review_scores_value                                           4.75
# license                                                        NaN
# instant_bookable                                               NaN
# calculated_host_listings_count                                 3.0
# calculated_host_listings_count_entire_homes                    1.0
# calculated_host_listings_count_private_rooms                   0.0
# calculated_host_listings_count_shared_rooms                    0.0
# reviews_per_month                                              0.5
#
#                                                                 75%  \
# id                                            1067266443718449536.0
# source                                                          NaN
# name                                                            NaN
# description                                                     NaN
# neighborhood_overview                                           NaN
# host_id                                                 415840703.0
# host_name                                                       NaN
# host_since                                                      NaN
# host_location                                                   NaN
# host_about                                                      NaN
# host_response_time                                              NaN
# host_response_rate                                              NaN
# host_acceptance_rate                                            NaN
# host_is_superhost                                               NaN
# host_neighbourhood                                              NaN
# host_listings_count                                            24.0
# host_total_listings_count                                      34.0
# host_verifications                                              NaN
# host_has_profile_pic                                            NaN
# host_identity_verified                                          NaN
# neighbourhood                                                   NaN
# neighbourhood_cleansed                                          NaN
# neighbourhood_group_cleansed                                    NaN
# latitude                                                  40.763902
# longitude                                                 -73.92338
# property_type                                                   NaN
# room_type                                                       NaN
# accommodates                                                    4.0
# bathrooms                                                       1.0
# bathrooms_text                                                  NaN
# bedrooms                                                        2.0
# beds                                                            2.0
# amenities                                                       NaN
# price                                                           NaN
# minimum_nights                                                 30.0
# maximum_nights                                                770.0
# minimum_minimum_nights                                         30.0
# maximum_minimum_nights                                         30.0
# minimum_maximum_nights                                       1125.0
# maximum_maximum_nights                                       1125.0
# minimum_nights_avg_ntm                                         30.0
# maximum_nights_avg_ntm                                       1125.0
# calendar_updated                                                NaN
# has_availability                                                NaN
# availability_30                                                29.0
# availability_60                                                59.0
# availability_90                                                89.0
# availability_365                                              352.0
# calendar_last_scraped                                           NaN
# number_of_reviews                                              35.0
# number_of_reviews_ltm                                           3.0
# number_of_reviews_l30d                                          0.0
# availability_eoy                                              296.0
# number_of_reviews_ly                                            3.0
# estimated_occupancy_l365d                                     120.0
# estimated_revenue_l365d                                     16500.0
# first_review                                                    NaN
# last_review                                                     NaN
# review_scores_rating                                            5.0
# review_scores_accuracy                                          5.0
# review_scores_cleanliness                                      4.98
# review_scores_checkin                                           5.0
# review_scores_communication                                     5.0
# review_scores_location                                          5.0
# review_scores_value                                            4.89
# license                                                         NaN
# instant_bookable                                                NaN
# calculated_host_listings_count                                 19.0
# calculated_host_listings_count_entire_homes                     6.0
# calculated_host_listings_count_private_rooms                    2.0
# calculated_host_listings_count_shared_rooms                     0.0
# reviews_per_month                                              1.49
#
#                                                                 max
# id                                            1366912874990325504.0
# source                                                          NaN
# name                                                            NaN
# description                                                     NaN
# neighborhood_overview                                           NaN
# host_id                                                 681436540.0
# host_name                                                       NaN
# host_since                                                      NaN
# host_location                                                   NaN
# host_about                                                      NaN
# host_response_time                                              NaN
# host_response_rate                                              NaN
# host_acceptance_rate                                            NaN
# host_is_superhost                                               NaN
# host_neighbourhood                                              NaN
# host_listings_count                                          5255.0
# host_total_listings_count                                    9055.0
# host_verifications                                              NaN
# host_has_profile_pic                                            NaN
# host_identity_verified                                          NaN
# neighbourhood                                                   NaN
# neighbourhood_cleansed                                          NaN
# neighbourhood_group_cleansed                                    NaN
# latitude                                                  40.911147
# longitude                                                 -73.71365
# property_type                                                   NaN
# room_type                                                       NaN
# accommodates                                                   16.0
# bathrooms                                                      15.5
# bathrooms_text                                                  NaN
# bedrooms                                                       15.0
# beds                                                           42.0
# amenities                                                       NaN
# price                                                           NaN
# minimum_nights                                                730.0
# maximum_nights                                              10000.0
# minimum_minimum_nights                                        730.0
# maximum_minimum_nights                                       1000.0
# minimum_maximum_nights                                 2147483647.0
# maximum_maximum_nights                                 2147483647.0
# minimum_nights_avg_ntm                                        861.8
# maximum_nights_avg_ntm                                 2147483647.0
# calendar_updated                                                NaN
# has_availability                                                NaN
# availability_30                                                30.0
# availability_60                                                60.0
# availability_90                                                90.0
# availability_365                                              365.0
# calendar_last_scraped                                           NaN
# number_of_reviews                                            2749.0
# number_of_reviews_ltm                                        1784.0
# number_of_reviews_l30d                                        135.0
# availability_eoy                                              305.0
# number_of_reviews_ly                                         1797.0
# estimated_occupancy_l365d                                     255.0
# estimated_revenue_l365d                                   1020050.0
# first_review                                                    NaN
# last_review                                                     NaN
# review_scores_rating                                            5.0
# review_scores_accuracy                                          5.0
# review_scores_cleanliness                                       5.0
# review_scores_checkin                                           5.0
# review_scores_communication                                     5.0
# review_scores_location                                          5.0
# review_scores_value                                             5.0
# license                                                         NaN
# instant_bookable                                                NaN
# calculated_host_listings_count                               1194.0
# calculated_host_listings_count_entire_homes                  1194.0
# calculated_host_listings_count_private_rooms                  616.0
# calculated_host_listings_count_shared_rooms                     4.0
# reviews_per_month                                            117.98

# %%
# 1차 전처리 columns
drop_cols = ['source','calendar_updated','calendar_last_scraped']

convert_tf_cols = ['host_is_superhost', 'host_has_profile_pic',
                'host_identity_verified','has_availability',
                'instant_bookable']

df['price'] = df['price'].str.replace('$','').str.replace(',','').astype('float')

df['host_since'] = pd.to_datetime(df['host_since'])

# 처리 함수
def convert_tf(df, cols):
    for col in cols:
        df[col] = df[col].map({'t':True, 'f':False}).astype('boolean')

    return df

df_cleaned = convert_tf(df, convert_tf_cols)
df_cleaned = df_cleaned.drop(columns = drop_cols)

# %%
df_cleaned.shape
# Out:
# (22308, 69)

# %%
from src import utils

fig, axs = plt.subplots(1,2)

sns.histplot(df_cleaned['price'], ax = axs[0])
axs[0].set_xlim(0,5000)

log_price = np.log(df_cleaned['price'] + 1)
sns.histplot(log_price, ax = axs[1])

utils.save_image(fig, '가격 히스토그램')
# Out:
# Successfully saved: docs/images/가격 히스토그램.png

# %%
from scipy.stats import shapiro, probplot

shapiro_stat, p_val = shapiro(log_price)
print('정규성 검정 결과:', p_val)

fig, axs = plt.subplots(1,2)

probplot(df_cleaned['price'], dist = 'norm', plot = axs[0])
probplot(log_price, dist = 'norm', plot = axs[1])
plt.tight_layout()
plt.show()

utils.save_image(fig, '가격 QQ plot')

print('왜도 : ', log_price.skew())
print('첨도 : ', log_price.kurt())
# Out:
# 정규성 검정 결과: 2.1864019793152053e-46
# Successfully saved: docs/images/가격 QQ plot.png
# 왜도 :  0.5681430454641385
# 첨도 :  1.0437562006959409

# %%
df_cleaned['log_price'] = np.log(df_cleaned['price'] + 1)
df_cleaned.shape
# Out:
# (22308, 70)

# %%
import pydeck as pdk

plot_df = df_cleaned[['latitude','longitude','price','log_price']].dropna().copy()
plot_df = plot_df.reset_index(drop = True)

plot_df['color_rate'] = (plot_df['log_price'] / plot_df['log_price'].max() * 255).astype(int)

# 지도 중심점 표시
view_state = pdk.ViewState(
    latitude = plot_df['latitude'].mean(),
    longitude = plot_df['longitude'].mean(),
    zoom = 10,
    pitch = 30
)

# 위치별 가격 정보 시각화
column_layer = pdk.Layer(
    'ColumnLayer',
    plot_df.to_dict('records'),
    get_position = ['longitude','latitude'],
    get_elevation = 'price', # 높이는 price
    elevation_scale = 0.5,
    radius = 100,
    get_fill_color = '[255, color_rate, 0, 140]',
    pickable=True,
    auto_highlight=True
)

r = pdk.Deck(layers=[column_layer], initial_view_state=view_state)
r.to_html("docs/images/price_elevation.html", notebook_display=False)

# %%
heatmap_layer = pdk.Layer(
    "HeatmapLayer",
    plot_df.to_dict('records'),
    get_position=["longitude", "latitude"],
    pickable = True,
    auto_highlight = True
)

r = pdk.Deck(layers=[heatmap_layer], initial_view_state=view_state)
r.to_html("docs/images/airbnb_heatmap.html", notebook_display = False)
